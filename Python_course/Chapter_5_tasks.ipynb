# %% [markdown]
# ## Task 1
# ### Load anyone dataset and do all types of Data Visualization along with Insights and submit the presentation in PPT format.

# %% [markdown]
# ### Step 1 - Dataset Discription
#
# **This dataset contains information about 30 individuals whose pulse rates were measured under different conditions of:**
#
# 1. Diet Type
# 2. Physical Activity
# 3. Time Duration
#
# The dataset is designed to study how exercise intensity and diet influence a person's pulse rate.
# Each participant's pulse was recorded at 1 minute, 15 minutes, and 30 minutes during different activities such as resting, walking, and running.

# %% [markdown]
# ### Step 2 - Import necessary libraries for visualization.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 3 - Load dataset

# %%
exercise_records = sns.load_dataset("exercise")
exercise_records.head(7)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest
# 5           5   2  low fat     93  30 min  rest
# 6           6   3  low fat     97   1 min  rest

# %% [markdown]
# ### Step 4 - Check for null values.
#
# * If no null values present inside the dataset, Then continue with other steps.

# %%
exercise_records.isna().sum()
# Out:
# Unnamed: 0    0
# id            0
# diet          0
# pulse         0
# time          0
# kind          0
# dtype: int64

# %% [markdown]
# ### Step 5 - Start to perform visualization based on (Uni,Bi and Multi variant analysis)

# %% [markdown]
# #### 5.1 UNIVARIATE ANALYSIS

# %%
# Histogram
# A. Distribution of Pulse rate.

sns.histplot(data = exercise_records, x = "pulse", kde=True)
plt.title("Distribution of Pulse rate")
plt.show()

# %%
# Boxplot
# B. Pulse Rate Distribution

sns.boxplot(data = exercise_records, x = "pulse")
plt.title("Pulse Rate Distribution")
plt.show()

# %%
# Violin Plot
# Pulse Rate Distribution

sns.violinplot(data = exercise_records, x = "pulse")
plt.title("Pulse Rate Distribution")
plt.show()

# %%
#Countplot

sns.countplot(data = car_crash_records, x = "kind")
plt.title("Activity Type Count")
plt.show()

# %%
car_crash_records["diet"].value_counts()
# Out:
# diet
# no fat     45
# low fat    45
# Name: count, dtype: int64

# %%
# D. Pie Chart
# Top 10 States by Fatal Crashes

plt.pie(x = car_crash_records["diet"].value_counts(), labels = ["45 No Fat","45 Low Fat"], explode= [0.01,0.01],autopct = "%1.0f%%")
plt.title("Diet Distribution")
plt.show()

# %% [markdown]
# #### 5.2 BIVARIATE ANALYSIS

# %%
# Barplot
# Diet vs pulse

sns.barplot(data = exercise_records, x = "diet", y = "pulse")
plt.title("Average Pulse by Diet")
plt.show()

# %%
# Barplot
# kind vs pulse vs diet

sns.barplot(data=exercise_records,x="kind",y="pulse", hue = "diet")
plt.title("Average Pulse by Activity")
plt.show()

# %%
# Boxplot with multiple features.

sns.boxplot(data=exercise_records,x="kind",y="pulse")
plt.show()

# %%
# Scatterplot
# id vs pulse

sns.scatterplot(data = exercise_records, x = "id", y = "pulse", hue = "kind")
plt.title("Pulse Rate by Participant")
plt.show()

# %%
# Pairplot

sns.pairplot(exercise_records,hue="kind")
plt.show()

# %% [markdown]
# #### 5.3 MULTIVARIATE ANALYSIS

# %%
exercise_records.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
# TO REPRESENT THE CORRELATION MATRIX , THEN DATASET SHOULD CONTAIN ONLY NUMERICAL VALUES. SO IAM GOING TO DEL THE STRING FEATURES.

del exercise_records["time"]
del exercise_records["kind"]

# %%
exercise_records.head()
# Out:
#    Unnamed: 0  id  pulse
# 0           0   1     85
# 1           1   1     85
# 2           2   1     88
# 3           3   2     90
# 4           4   2     92

# %%
excercise_matrix_corr = exercise_records.corr().round(2)
excercise_matrix_corr
# Out:
#             Unnamed: 0    id  pulse
# Unnamed: 0        1.00  1.00   0.69
# id                1.00  1.00   0.68
# pulse             0.69  0.68   1.00

# %%
sns.heatmap(data = excercise_matrix_corr, annot=True)
plt.show()

# %%
new_excercise_data = sns.load_dataset("exercise")
new_excercise_data
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
#Line Plot
#time vs pulse

sns.lineplot(data = new_excercise_data, x = "time", y = "pulse", hue = "kind", markers=0 )
plt.title("Pulse Rate Over Time")
plt.show()
