# %% [markdown]
# ## 1. Perform initial analysis
#
# * rows - Records/observation
# * column - Features/Parameters

# %%
import pandas as pd

# %%
restaurent_details = pd.read_csv(filepath_or_buffer = "dataset.csv")
restaurent_details
# Out:
#      Restaurant_ID Restaurant_Name   Cuisine         City State  Rating  \
# 0            R0185      BBQ Nation  American       Dallas    TX     5.0
# 1            R0129    Pizza Palace   Italian      Chicago    IL     3.7
# 2            R0253      BBQ Nation  American  Los Angeles    CA     3.9
# 3            R0043      BBQ Nation  American      Chicago    IL     4.6
# 4            R0028      Dragon Wok   Chinese       Dallas    TX     3.7
# ...            ...             ...       ...          ...   ...     ...
# 1995         R0201     Spice Route    Indian      Phoenix    AZ     4.1
# 1996         R0158    Healthy Bowl   Healthy       Boston    MA     4.4
# 1997         R0266    Healthy Bowl   Healthy       Boston    MA     4.3
# 1998         R0206    Healthy Bowl   Healthy  Los Angeles    CA     3.5
# 1999         R0253    Cafe Delight      Cafe  Los Angeles    CA     4.0
#
#       Delivery_Time_Min       Menu_Item     Category   Price  Calories Is_Veg
# ...

# %%
# Functions - ()
# Attributes - None

restaurent_details.shape

# We need to say like , the client provided 10 obervations with 8 parameters
# Out:
# (2000, 12)

# %%
# Chain of function - Using function in continues
# isnull()          - Checks any null values are present inside the dataset
# sum()             - It will gives sum of all null values inside the dataset

restaurent_details.isnull().sum()
# Out:
# Restaurant_ID        0
# Restaurant_Name      0
# Cuisine              0
# City                 0
# State                0
# Rating               0
# Delivery_Time_Min    0
# Menu_Item            0
# Category             0
# Price                0
# Calories             0
# Is_Veg               0
# dtype: int64

# %%
restaurent_details.dtypes
# Out:
# Restaurant_ID         object
# Restaurant_Name       object
# Cuisine               object
# City                  object
# State                 object
# Rating               float64
# Delivery_Time_Min      int64
# Menu_Item             object
# Category              object
# Price                 object
# Calories               int64
# Is_Veg                object
# dtype: object

# %%
# describe() - Satestical representation

restaurent_details.describe(include = 'all')
# Out:
#        Restaurant_ID Restaurant_Name   Cuisine     City State       Rating  \
# count           2000            2000      2000     2000  2000  2000.000000
# unique           300              10         9        8     7          NaN
# top            R0286    Healthy Bowl  American  Houston    TX          NaN
# freq              14             228       377      272   498          NaN
# mean             NaN             NaN       NaN      NaN   NaN     4.244800
# std              NaN             NaN       NaN      NaN   NaN     0.429459
# min              NaN             NaN       NaN      NaN   NaN     3.500000
# 25%              NaN             NaN       NaN      NaN   NaN     3.900000
# 50%              NaN             NaN       NaN      NaN   NaN     4.200000
# 75%              NaN             NaN       NaN      NaN   NaN     4.600000
# max              NaN             NaN       NaN      NaN   NaN     5.000000
#
# ...

# %% [markdown]
# ### 1.1 Find out menu items.

# %%
# It gives the number of unique values of whole dataset

restaurent_details.nunique()
# Out:
# Restaurant_ID        300
# Restaurant_Name       10
# Cuisine                9
# City                   8
# State                  7
# Rating                16
# Delivery_Time_Min     46
# Menu_Item             10
# Category               5
# Price                 10
# Calories             933
# Is_Veg                 2
# dtype: int64

# %%
# I need only "Menu_Item" so iam using unique. Iam slicing parameters to pick one observation so that's why iam using [].

print(restaurent_details["Menu_Item"].unique())
# Out:
# ['Butter Chicken' 'Taco' 'Sushi Roll' 'Coffee' 'Burger' 'Salad' 'Pizza'
#  'Noodles' 'Pasta' 'Paneer Tikka']

# %% [markdown]
# ### 1.2 Finding Top 5 selling items.
#
# * Step_1 = Iam using groupby() to combinie two obervations as a output (items,Rating).
# * Step_2 = Iam using sum() to see the items.
# * step_3 = Using sort_value() will makes the dataset in asending order.
# * step_4 = To see top 5 salary i need to reverse it so i make the ascendinig = False.
# * step_5 = To visualize top 5 i used head()

# %%
# Used chain methods

restaurent_details.groupby(by = "Menu_Item")["Rating"].sum().sort_values(ascending = False).head()
# Out:
# Menu_Item
# Salad             945.3
# Pasta             942.1
# Sushi Roll        902.9
# Pizza             892.5
# Butter Chicken    883.9
# Name: Rating, dtype: float64

# %% [markdown]
# ### 1.2 Finding Least 5 salary brought by the employees

# %%
# Used chain methods

restaurent_details.groupby(by = "Menu_Item")["Rating"].sum().sort_values().head()
# Out:
# Menu_Item
# Paneer Tikka    717.3
# Noodles         751.6
# Taco            762.9
# Burger          826.0
# Coffee          865.1
# Name: Rating, dtype: float64

# %% [markdown]
# ## Data Cleaning

# %%
# I need to change the price data (object) into numbers

restaurent_details
# Out:
#      Restaurant_ID Restaurant_Name   Cuisine         City State  Rating  \
# 0            R0185      BBQ Nation  American       Dallas    TX     5.0
# 1            R0129    Pizza Palace   Italian      Chicago    IL     3.7
# 2            R0253      BBQ Nation  American  Los Angeles    CA     3.9
# 3            R0043      BBQ Nation  American      Chicago    IL     4.6
# 4            R0028      Dragon Wok   Chinese       Dallas    TX     3.7
# ...            ...             ...       ...          ...   ...     ...
# 1995         R0201     Spice Route    Indian      Phoenix    AZ     4.1
# 1996         R0158    Healthy Bowl   Healthy       Boston    MA     4.4
# 1997         R0266    Healthy Bowl   Healthy       Boston    MA     4.3
# 1998         R0206    Healthy Bowl   Healthy  Los Angeles    CA     3.5
# 1999         R0253    Cafe Delight      Cafe  Los Angeles    CA     4.0
#
#       Delivery_Time_Min       Menu_Item     Category   Price  Calories Is_Veg
# ...

# %%
restaurent_details["Price"].str.replace("$","")
# Out:
# 0       13.99
# 1        4.99
# 2        4.99
# 3       11.99
# 4        3.99
#         ...
# 1995     8.99
# 1996    13.99
# 1997    12.99
# 1998     7.49
# 1999    13.99
# Name: Price, Length: 2000, dtype: object

# %%
# changing the object into float

restaurent_details["Price"].str.replace("$","").astype(float)
# Out:
# 0       13.99
# 1        4.99
# 2        4.99
# 3       11.99
# 4        3.99
#         ...
# 1995     8.99
# 1996    13.99
# 1997    12.99
# 1998     7.49
# 1999    13.99
# Name: Price, Length: 2000, dtype: float64

# %%
# To store in dataset 

restaurent_details
# Out:
#      Restaurant_ID Restaurant_Name   Cuisine         City State  Rating  \
# 0            R0185      BBQ Nation  American       Dallas    TX     5.0
# 1            R0129    Pizza Palace   Italian      Chicago    IL     3.7
# 2            R0253      BBQ Nation  American  Los Angeles    CA     3.9
# 3            R0043      BBQ Nation  American      Chicago    IL     4.6
# 4            R0028      Dragon Wok   Chinese       Dallas    TX     3.7
# ...            ...             ...       ...          ...   ...     ...
# 1995         R0201     Spice Route    Indian      Phoenix    AZ     4.1
# 1996         R0158    Healthy Bowl   Healthy       Boston    MA     4.4
# 1997         R0266    Healthy Bowl   Healthy       Boston    MA     4.3
# 1998         R0206    Healthy Bowl   Healthy  Los Angeles    CA     3.5
# 1999         R0253    Cafe Delight      Cafe  Los Angeles    CA     4.0
#
#       Delivery_Time_Min       Menu_Item     Category  Price  Calories Is_Veg
# ...

# %%
restaurent_details.dtypes
# Out:
# Restaurant_ID         object
# Restaurant_Name       object
# Cuisine               object
# City                  object
# State                 object
# Rating               float64
# Delivery_Time_Min      int64
# Menu_Item             object
# Category              object
# Price                float64
# Calories               int64
# Is_Veg                object
# dtype: object

# %%
restaurent_details.describe()
# Out:
#             Rating  Delivery_Time_Min        Price     Calories
# count  2000.000000        2000.000000  2000.000000  2000.000000
# mean      4.244800          37.886500     9.590500   635.809500
# std       0.429459          13.539841     3.116449   319.611187
# min       3.500000          15.000000     3.990000    81.000000
# 25%       3.900000          26.000000     7.490000   348.750000
# 50%       4.200000          38.000000    10.490000   646.500000
# 75%       4.600000          50.000000    11.990000   910.250000
# max       5.000000          60.000000    13.990000  1200.000000

# %% [markdown]
# ### 3. Pandas Data Structure
# - 1D - series
# - 2D - DataFrame

# %%
# 1D - Series

import pandas as pd

pd.Series(data = [1,2,3.5,"$4.6"])
# Out:
# 0       1
# 1       2
# 2     3.5
# 3    $4.6
# dtype: object

# %%
# 2D - DataFrame

pd.DataFrame(data = [1,2,3.5,"$4.6"])
# Out:
#       0
# 0     1
# 1     2
# 2   3.5
# 3  $4.6

# %% [markdown]
# ## 4. Filtering & Selection & Sorting

# %%
euro_footbal = pd.read_csv("Euro_2012.csv")
euro_footbal
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Display all obervations

pd.set_option("display.max_column",None)

# %%
euro_footbal.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# ### Filtering

# %%
# Iam going to filter important observations.
# If the observations are more than one , then use [].
# For slicing some observations from the datasets use [].

filtered_euro = euro_footbal[["Team","Goals","Yellow Cards","Red Cards"]]

# %%
filtered_euro.head()
# Out:
#              Team  Goals  Yellow Cards  Red Cards
# 0         Croatia      4             9          0
# 1  Czech Republic      4             7          0
# 2         Denmark      4             4          0
# 3         England      5             5          0
# 4          France      3             6          0

# %% [markdown]
# ##  Sorting
# ### Top 5 Team to conceed more yellow card

# %%
filtered_euro.sort_values(by = "Yellow Cards",ascending = False).head(6)
# Out:
#               Team  Goals  Yellow Cards  Red Cards
# 7            Italy      6            16          0
# 10        Portugal      6            12          0
# 13           Spain     12            11          0
# 0          Croatia      4             9          0
# 6           Greece      5             9          1
# 1   Czech Republic      4             7          0

# %% [markdown]
# ### Top 5 Team to conceed more Red card

# %%
filtered_euro.sort_values("Red Cards",ascending = False).head()
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0

# %% [markdown]
# ### List the Team which as more than 8 Yellow cards

# %%
filtered_euro[filtered_euro["Yellow Cards"] >= 8]
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 0    Croatia      4             9          0
# 6     Greece      5             9          1
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0

# %% [markdown]
# # 4. How to deal with Missing Values

# %% [markdown]
# ## Level - 1 of Data Cleaning

# %%
employee_data = pd.read_csv("emp_data.csv")
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %% [markdown]
# ### Step 1 - Remove Duplicate data

# %%
employee_data.shape
# Out:
# (8, 5)

# %%
employee_data.drop_duplicates(inplace = True)

# To save this updated data into current data, i will use inplace = True

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %% [markdown]
# ### Step 2 - Find null values

# %%
employee_data.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        1
# Join_Date     0
# dtype: int64

# %% [markdown]
# ### Step 3 - Founded three null values, Going to drop it.

# %%
employee_data.dropna(inplace = True)

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
employee_data.shape
# Out:
# (4, 5)

# %% [markdown]
# ### Step 4 - Documentation
#
# * Removed 1 duplicate data
# * Removed 3 null data
# * Observation and Perameters are Before (8,5)
# * Observation and Perameters are Now (4,5)
# * Sending this updated file to client for approval, If client approved then, proceed with model buil

# %% [markdown]
# ## Level - 2 of Data Cleaning
#
# * readcsv - It will read only one csv sheet.
# * readexcel - It will access multiple sheets which inside one dataset. Using sheet names.

# %%
# So if you are having csv file but u need to access different sheets, Then you need to change the csv file into excel file.
# And then access it with sheet name.

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
new_employee = pd.read_excel("emp_data_excel.xlsx",sheet_name ="More_employee_data")
new_employee
# Out:
#             Name   Age Department   Salary  Join_Date
# 0         Rajesh  29.0        Ops  60000.0 2023-05-21
# 1          Nasir  31.0    IT Tech  62000.0 2020-11-12
# 2         Mathew   NaN    Support  50000.0 2025-01-15
# 3        Gilbert  29.0        Ops  60000.0 2021-05-21
# 4          Kevin  28.0    Support  61000.0 2024-07-30
# 5          Navin  35.0    Support  72000.0 2023-08-19
# 6            NaN  40.0    IT Tech  64000.0 2022-09-10
# 7         Roshan  31.0    IT Tech      NaN 2020-11-12
# 8      Kuppusamy  28.0        Ops      NaN 2021-05-21
# 9          Ajesh  28.0    Support      NaN 2024-07-30
# 10          Diya  31.0    IT Tech  63000.0 2020-11-12
# 11        Mathew   NaN    Support  50000.0 2025-01-15
# 12  Jagadheswari  28.0    IT Tech      NaN        NaT
# 13          Mani  28.0        Ops      NaN 2021-05-21

# %% [markdown]
# #### Follow same steps to clean data

# %%
# Remove duplicate

new_employee.drop_duplicates(inplace = True)
new_employee
# Out:
#             Name   Age Department   Salary  Join_Date
# 0         Rajesh  29.0        Ops  60000.0 2023-05-21
# 1          Nasir  31.0    IT Tech  62000.0 2020-11-12
# 2         Mathew   NaN    Support  50000.0 2025-01-15
# 3        Gilbert  29.0        Ops  60000.0 2021-05-21
# 4          Kevin  28.0    Support  61000.0 2024-07-30
# 5          Navin  35.0    Support  72000.0 2023-08-19
# 6            NaN  40.0    IT Tech  64000.0 2022-09-10
# 7         Roshan  31.0    IT Tech      NaN 2020-11-12
# 8      Kuppusamy  28.0        Ops      NaN 2021-05-21
# 9          Ajesh  28.0    Support      NaN 2024-07-30
# 10          Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheswari  28.0    IT Tech      NaN        NaT
# 13          Mani  28.0        Ops      NaN 2021-05-21

# %%
# Find and remove null values

new_employee.isna().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        5
# Join_Date     1
# dtype: int64

# %% [markdown]
# ## Try to find patten and impute data before dropping it.
# * Finding exact place of null values.

# %%
new_employee[new_employee["Department"] == "Support"]
# Out:
#      Name   Age Department   Salary  Join_Date
# 2  Mathew   NaN    Support  50000.0 2025-01-15
# 4   Kevin  28.0    Support  61000.0 2024-07-30
# 5   Navin  35.0    Support  72000.0 2023-08-19
# 9   Ajesh  28.0    Support      NaN 2024-07-30

# %%
new_employee[ (new_employee["Department"] == "Support") & (new_employee["Salary"].isna()) ]
# Out:
#     Name   Age Department  Salary  Join_Date
# 9  Ajesh  28.0    Support     NaN 2024-07-30

# %%
new_employee[new_employee["Department"] == "IT Tech"]
# Out:
#             Name   Age Department   Salary  Join_Date
# 1          Nasir  31.0    IT Tech  62000.0 2020-11-12
# 6            NaN  40.0    IT Tech  64000.0 2022-09-10
# 7         Roshan  31.0    IT Tech      NaN 2020-11-12
# 10          Diya  31.0    IT Tech  63000.0 2020-11-12
# 12  Jagadheswari  28.0    IT Tech      NaN        NaT

# %%
new_employee[ (new_employee["Department"] == "IT Tech") & (new_employee["Salary"].isna()) ]
# Out:
#             Name   Age Department  Salary  Join_Date
# 7         Roshan  31.0    IT Tech     NaN 2020-11-12
# 12  Jagadheswari  28.0    IT Tech     NaN        NaT

# %%
new_employee[ (new_employee["Department"] == "Ops") & (new_employee["Salary"].isna()) ]
# Out:
#          Name   Age Department  Salary  Join_Date
# 8   Kuppusamy  28.0        Ops     NaN 2021-05-21
# 13       Mani  28.0        Ops     NaN 2021-05-21

# %%
new_employee[ (new_employee["Department"] == "Support") & (new_employee["Age"].isna()) ]
# Out:
#      Name  Age Department   Salary  Join_Date
# 2  Mathew  NaN    Support  50000.0 2025-01-15
